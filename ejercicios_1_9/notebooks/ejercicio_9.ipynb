# %%
import sys

import os

sys.path.append(os.path.abspath("../src"))

from funciones_ejercicios1_9 import nombre_valido, nota_valida, normalizar_registro, eliminar_duplicados

students = [
{"name": "  Ana García ", "grade": "8", "status":
"aprobado"},
{"name": "pedro lópez", "grade": "4", "status":
"DESAPROBADO"},
{"name": "MARÍA FERNÁNDEZ", "grade": "10", "status":
"Aprobado"},
{"name": "ana garcía", "grade": "9", "status":
"aprobado"},
{"name": None, "grade": "7", "status": "aprobado"},
{"name": "Luis Martínez  ", "grade": None, "status":
"aprobado"},
{"name": " carlos RUIZ", "grade": "6", "status":
"aprobado"},
{"name": "PEDRO LÓPEZ ", "grade": "3", "status":
"desaprobado"},
{"name": "  ", "grade": "5", "status": "aprobado"},
{"name": "María Fernández", "grade": "7", "status":
"APROBADO"},
{"name": "Sofía Torres", "grade": "9", "status":
"Aprobado"},
{"name": "  sofía torres ", "grade": "8", "status":
"aprobado"},
{"name": "Carlos Ruiz", "grade": "6", "status":
"APROBADO"},
{"name": "Roberto Díaz", "grade": "absent", "status":
"ausente"},
{"name": "roberto díaz", "grade": "", "status":
"Ausente"},
{"name": None, "grade": None, "status": None},
{"name": "Laura Méndez", "grade": "7", "status":
"aprobado"},
{"name": "  laura méndez", "grade": "8", "status":
"Aprobado"},
{"name": "GABRIELA RÍOS", "grade": "5", "status":
"aprobado"},
{"name": "gabriela ríos ", "grade": "4", "status":
"Desaprobado"},
]

limpios = []

for s in students:
    if nombre_valido(s["name"]):
        if nota_valida(s["grade"]):
            limpio = normalizar_registro(s)
            limpios.append(limpio)

sin_duplicados = eliminar_duplicados(limpios)

ordenados = sorted(sin_duplicados, key=lambda x: x["name"])

print ("Listado final de alumnos:")
print(f"{'Nombre':<20}{'Nota':<10}{'Estado':<15}")
print("-" * 45)

for alumno in ordenados:
     print(f"{alumno['name']:<20}{alumno['grade']:<10}{alumno['status']:<15}")

print("\nCantidad total de alumnos válidos:", len(ordenados))
