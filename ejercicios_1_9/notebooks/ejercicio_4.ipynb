# %%
import sys

import os

sys.path.append(os.path.abspath("../src"))

from funciones_ejercicios1_9 import es_email_valido

email = input("Ingrese un email:")

print (email)

if (es_email_valido(email)):
    print("El email es válido")
else:
    print("El email no es válido")
